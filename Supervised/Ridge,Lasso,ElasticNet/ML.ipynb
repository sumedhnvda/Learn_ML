# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("Algerian_forest_fires_dataset_UPDATE.csv",header=1)

# %%
df.head()
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0  01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1  02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2  03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3  04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4  05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#      Classes
# 0  not fire
# 1  not fire
# 2  not fire
# 3  not fire
# 4  not fire

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246 entries, 0 to 245
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          246 non-null    object
#  1   month        245 non-null    object
#  2   year         245 non-null    object
#  3   Temperature  245 non-null    object
#  4    RH          245 non-null    object
#  5    Ws          245 non-null    object
#  6   Rain         245 non-null    object
#  7   FFMC         245 non-null    object
#  8   DMC          245 non-null    object
#  9   DC           245 non-null    object
#  10  ISI          245 non-null    object
#  11  BUI          245 non-null    object
#  12  FWI          245 non-null    object
#  13  Classes      244 non-null    object
# dtypes: object(14)
# memory usage: 27.0+ KB

# %%
df[df.isnull().any(axis=1)]
# Out:
#                                day month  year Temperature   RH   Ws Rain   \
# 122  Sidi-Bel Abbes Region Dataset   NaN   NaN         NaN  NaN  NaN   NaN
# 167                             14    07  2012          37   37   18   0.2
#
#      FFMC   DMC      DC   ISI   BUI      FWI Classes
# 122   NaN   NaN     NaN   NaN   NaN      NaN       NaN
# 167  88.9  12.9  14.6 9  12.5  10.4  fire          NaN

# %%
df.loc[:122,"Region"]=0
df.loc[122:,"Region"]=1
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246 entries, 0 to 245
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          246 non-null    object
#  1   month        245 non-null    object
#  2   year         245 non-null    object
#  3   Temperature  245 non-null    object
#  4    RH          245 non-null    object
#  5    Ws          245 non-null    object
#  6   Rain         245 non-null    object
#  7   FFMC         245 non-null    object
#  8   DMC          245 non-null    object
#  9   DC           245 non-null    object
#  10  ISI          245 non-null    object
#  11  BUI          245 non-null    object
#  12  FWI          245 non-null    object
#  13  Classes      244 non-null    object
#  14  Region       246 non-null    float64
# dtypes: float64(1), object(14)
# memory usage: 29.0+ KB

# %%
df["Region"]=df["Region"].astype(int)

# %%
df.head()
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0  01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1  02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2  03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3  04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4  05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#      Classes    Region
# 0  not fire          0
# 1  not fire          0
# 2  not fire          0
# 3  not fire          0
# 4  not fire          0

# %%
df[df.isnull().any(axis=1)]
# Out:
#                                day month  year Temperature   RH   Ws Rain   \
# 122  Sidi-Bel Abbes Region Dataset   NaN   NaN         NaN  NaN  NaN   NaN
# 167                             14    07  2012          37   37   18   0.2
#
#      FFMC   DMC      DC   ISI   BUI      FWI Classes    Region
# 122   NaN   NaN     NaN   NaN   NaN      NaN       NaN       1
# 167  88.9  12.9  14.6 9  12.5  10.4  fire          NaN       1

# %%
df.dropna(inplace=True)
df.reset_index(drop=True, inplace=True)

# %%
df[df.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [day, month, year, Temperature,  RH,  Ws, Rain , FFMC, DMC, DC, ISI, BUI, FWI, Classes  , Region]
# Index: []

# %%
df.loc[[122]]
# Out:
#      day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC  DC  ISI  BUI  \
# 122  day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC  DC  ISI  BUI
#
#      FWI  Classes    Region
# 122  FWI  Classes         1

# %%
df.drop(122,inplace=True)
df.reset_index(drop=True,inplace=True)

# %%
df.loc[[122]]
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC   DC  ISI  BUI  FWI  \
# 122  01    06  2012          32  71  12   0.7  57.1  2.5  8.2  0.6  2.8  0.2
#
#        Classes    Region
# 122  not fire          1

# %%
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', ' RH', ' Ws', 'Rain ', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes  ', 'Region'],
#       dtype='object')

# %%
df.columns=df.columns.str.strip()

# %%
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes', 'Region'],
#       dtype='object')

# %%
df.head()
# Out:
#   day month  year Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI  \
# 0  01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1  02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2  03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3  04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4  05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#        Classes  Region
# 0  not fire          0
# 1  not fire          0
# 2  not fire          0
# 3  not fire          0
# 4  not fire          0

# %%
df[["day",'month','year',"Temperature",'RH','Ws']]=df[["day",'month','year',"Temperature",'RH','Ws']].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    int64
#  1   month        243 non-null    int64
#  2   year         243 non-null    int64
#  3   Temperature  243 non-null    int64
#  4   RH           243 non-null    int64
#  5   Ws           243 non-null    int64
#  6   Rain         243 non-null    object
#  7   FFMC         243 non-null    object
#  8   DMC          243 non-null    object
#  9   DC           243 non-null    object
#  10  ISI          243 non-null    object
#  11  BUI          243 non-null    object
#  12  FWI          243 non-null    object
#  13  Classes      243 non-null    object
#  14  Region       243 non-null    int64
# dtypes: int64(7), object(8)
# memory usage: 28.6+ KB

# %%
df[["Rain","FFMC","DMC","DC","ISI","BUI","FWI"]]=df[["Rain","FFMC","DMC","DC","ISI","BUI","FWI"]].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    int64
#  1   month        243 non-null    int64
#  2   year         243 non-null    int64
#  3   Temperature  243 non-null    int64
#  4   RH           243 non-null    int64
#  5   Ws           243 non-null    int64
#  6   Rain         243 non-null    float64
#  7   FFMC         243 non-null    float64
#  8   DMC          243 non-null    float64
#  9   DC           243 non-null    float64
#  10  ISI          243 non-null    float64
#  11  BUI          243 non-null    float64
#  12  FWI          243 non-null    float64
#  13  Classes      243 non-null    object
#  14  Region       243 non-null    int64
# dtypes: float64(7), int64(7), object(1)
# memory usage: 28.6+ KB

# %%
df['Classes']=df["Classes"].str.strip().replace({'not fire': 0, 'fire': 1}) #use map isnted of replace
# Out:
# C:\Users\Sumed\AppData\Local\Temp\ipykernel_16472\2654541787.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Classes']=df["Classes"].str.strip().replace({'not fire': 0, 'fire': 1})

# %%
df["Classes"]
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 238    1
# 239    0
# 240    0
# 241    0
# 242    0
# Name: Classes, Length: 243, dtype: int64

# %%
df['Classes'].unique()
# Out:
# array([0, 1])

# %%
df.head()
# Out:
#    day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  \
# 0    1      6  2012           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4
# 1    2      6  2012           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9
# 2    3      6  2012           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7
# 3    4      6  2012           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7
# 4    5      6  2012           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9
#
#    FWI  Classes  Region
# 0  0.5        0       0
# 1  0.4        0       0
# 2  0.1        0       0
# 3  0.0        0       0
# 4  0.5        0       0

# %%
df.to_csv("dataset.csv",index=False)

# %%
df_copy=df.drop(['day','month',"year"],axis=1)

# %%
df_copy.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI  Classes  Region
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4  0.5        0       0
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9  0.4        0       0
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1        0       0
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7  0.0        0       0
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9  0.5        0       0

# %%
df_copy.corr()
# Out:
#              Temperature        RH        Ws      Rain      FFMC       DMC  \
# Temperature     1.000000 -0.651400 -0.284510 -0.326492  0.676568  0.485687
# RH             -0.651400  1.000000  0.244048  0.222356 -0.644873 -0.408519
# Ws             -0.284510  0.244048  1.000000  0.171506 -0.166548 -0.000721
# Rain           -0.326492  0.222356  0.171506  1.000000 -0.543906 -0.288773
# FFMC            0.676568 -0.644873 -0.166548 -0.543906  1.000000  0.603608
# DMC             0.485687 -0.408519 -0.000721 -0.288773  0.603608  1.000000
# DC              0.376284 -0.226941  0.079135 -0.298023  0.507397  0.875925
# ISI             0.603871 -0.686667  0.008532 -0.347484  0.740007  0.680454
# BUI             0.459789 -0.353841  0.031438 -0.299852  0.592011  0.982248
# FWI             0.566670 -0.580957  0.032368 -0.324422  0.691132  0.875864
# Classes         0.516015 -0.432161 -0.069964 -0.379097  0.769492  0.585658
# Region          0.269555 -0.402682 -0.181160 -0.040013  0.222241  0.192089
#
#                    DC       ISI       BUI       FWI   Classes    Region
# Temperature  0.376284  0.603871  0.459789  0.566670  0.516015  0.269555
# RH          -0.226941 -0.686667 -0.353841 -0.580957 -0.432161 -0.402682
# Ws           0.079135  0.008532  0.031438  0.032368 -0.069964 -0.181160
# Rain        -0.298023 -0.347484 -0.299852 -0.324422 -0.379097 -0.040013
# FFMC         0.507397  0.740007  0.592011  0.691132  0.769492  0.222241
# DMC          0.875925  0.680454  0.982248  0.875864  0.585658  0.192089
# DC           1.000000  0.508643  0.941988  0.739521  0.511123 -0.078734
# ISI          0.508643  1.000000  0.644093  0.922895  0.735197  0.263197
# BUI          0.941988  0.644093  1.000000  0.857973  0.586639  0.089408
# FWI          0.739521  0.922895  0.857973  1.000000  0.719216  0.197102
# Classes      0.511123  0.735197  0.586639  0.719216  1.000000  0.162347
# Region      -0.078734  0.263197  0.089408  0.197102  0.162347  1.000000

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df_copy.corr(),annot=True)
plt.show()

# %%
df=pd.read_csv("dataset.csv")
df.head()
# Out:
#    day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  \
# 0    1      6  2012           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4
# 1    2      6  2012           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9
# 2    3      6  2012           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7
# 3    4      6  2012           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7
# 4    5      6  2012           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9
#
#    FWI  Classes  Region
# 0  0.5        0       0
# 1  0.4        0       0
# 2  0.1        0       0
# 3  0.0        0       0
# 4  0.5        0       0

# %%
df.drop(["day","month","year"],inplace=True,axis=1)

# %%
df.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI  Classes  Region
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4  0.5        0       0
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9  0.4        0       0
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1        0       0
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7  0.0        0       0
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9  0.5        0       0

# %%
X=df.iloc[:,:-3]
Y=df.iloc[:,-3]

# %%
X.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9

# %%
Y.head()
# Out:
# 0    0.5
# 1    0.4
# 2    0.1
# 3    0.0
# 4    0.5
# Name: FWI, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.25,random_state=42)

# %%
#for better model remove higly corr features
X_train.drop(["DMC","DC","BUI"],axis=1,inplace=True)
X_test.drop(["DMC","DC","BUI"],axis=1,inplace=True)

# %%
X_test.shape
# Out:
# (61, 6)

# %%
from sklearn.preprocessing import StandardScaler
scalar=StandardScaler()
X_train=scalar.fit_transform(X_train)
X_test=scalar.transform(X_test)

# %%
X_train
# Out:
# array([[-0.84284248,  0.78307967,  1.29972026, -0.33727373, -0.12805583,
#         -0.62963326],
#        [-0.30175842,  0.64950844, -0.59874754, -0.29048728, -1.21758569,
#         -0.93058524],
#        [ 2.13311985, -2.08870172, -0.21905398, -0.38406017,  1.15703067,
#          2.7271388 ],
#        ...,
#        [-1.9250106 ,  0.9166509 ,  0.54033314,  2.984564  , -2.20933724,
#         -1.06948615],
#        [ 0.50986767, -0.21870454,  0.16063958, -0.38406017,  0.73099656,
#          0.5973248 ],
#        [-0.57230045,  0.98343651,  2.05910739,  0.45809587, -1.33631651,
#         -0.86113478]], shape=(182, 6))

# %%
from sklearn.linear_model import LinearRegression
Lr=LinearRegression()
Lr.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
y_pred=Lr.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error,r2_score
mse=mean_squared_error(Y_test,y_pred)
r2=r2_score(Y_test,y_pred)
print(mse,r2)
plt.scatter(Y_test,y_pred)
# Out:
# 6.062506605945439 0.8630268357877738

# %%
#lasso
from sklearn.linear_model import Lasso
Lr=Lasso()
Lr.fit(X_train,Y_train)
# Out:
# Lasso()

# %%
y_pred=Lr.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error,r2_score
mse=mean_squared_error(Y_test,y_pred)
r2=r2_score(Y_test,y_pred)
print(mse,r2)
plt.scatter(Y_test,y_pred)
# Out:
# 7.326597351582449 0.834466617954528

# %%
#ridge
from sklearn.linear_model import Ridge
Lr=Ridge()
Lr.fit(X_train,Y_train)
# Out:
# Ridge()

# %%
y_pred=Lr.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error,r2_score
mse=mean_squared_error(Y_test,y_pred)
r2=r2_score(Y_test,y_pred)
print(mse,r2)
plt.scatter(Y_test,y_pred)
# Out:
# 6.102666460815297 0.8621194846286949

# %%
#elasticnet
from sklearn.linear_model import ElasticNet
Lr=ElasticNet()
Lr.fit(X_train,Y_train)
# Out:
# ElasticNet()

# %%
y_pred=Lr.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error,r2_score
mse=mean_squared_error(Y_test,y_pred)
r2=r2_score(Y_test,y_pred)
print(mse,r2)
plt.scatter(Y_test,y_pred)
# Out:
# 12.540832621841137 0.7166588611408851

# %%
#lasso
from sklearn.linear_model import LassoCV
Lr=LassoCV(cv=5)
Lr.fit(X_train,Y_train)
# Out:
# LassoCV(cv=5)

# %%
Lr.alpha_
# Out:
# np.float64(0.007058530018715199)

# %%
Lr.alphas_
# Out:
# array([7.05853002, 6.58280872, 6.13914944, 5.72539132, 5.33951911,
#        4.97965339, 4.64404142, 4.33104857, 4.03915039, 3.76692517,
#        3.51304702, 3.27627941, 3.05546914, 2.84954075, 2.65749124,
#        2.47838523, 2.31135036, 2.15557308, 2.01029467, 1.87480753,
#        1.74845178, 1.63061198, 1.52071419, 1.41822315, 1.32263965,
#        1.23349817, 1.15036452, 1.0728338 , 1.00052839, 0.93309613,
#        0.87020857, 0.81155943, 0.75686304, 0.705853  , 0.65828087,
#        0.61391494, 0.57253913, 0.53395191, 0.49796534, 0.46440414,
#        0.43310486, 0.40391504, 0.37669252, 0.3513047 , 0.32762794,
#        0.30554691, 0.28495408, 0.26574912, 0.24783852, 0.23113504,
#        0.21555731, 0.20102947, 0.18748075, 0.17484518, 0.1630612 ,
#        0.15207142, 0.14182231, 0.13226397, 0.12334982, 0.11503645,
#        0.10728338, 0.10005284, 0.09330961, 0.08702086, 0.08115594,
#        0.0756863 , 0.0705853 , 0.06582809, 0.06139149, 0.05725391,
#        0.05339519, 0.04979653, 0.04644041, 0.04331049, 0.0403915 ,
#        0.03766925, 0.03513047, 0.03276279, 0.03055469, 0.02849541,
#        0.02657491, 0.02478385, 0.0231135 , 0.02155573, 0.02010295,
#        0.01874808, 0.01748452, 0.01630612, 0.01520714, 0.01418223,
#        0.0132264 , 0.01233498, 0.01150365, 0.01072834, 0.01000528,
#        0.00933096, 0.00870209, 0.00811559, 0.00756863, 0.00705853])

# %%
Lr.mse_path_
# Out:
# array([[53.64536329, 65.39074075, 54.89628985, 77.90299066, 39.38236846],
#        [47.26825958, 59.81506814, 49.37033934, 75.6645852 , 35.31758355],
#        [41.72952256, 53.9178721 , 42.74366813, 68.35708298, 31.76996123],
#        [36.9194323 , 48.71817989, 37.17519591, 61.92819453, 28.67296816],
#        [32.74259519, 44.12989994, 32.51394424, 56.26841266, 25.96868127],
#        [29.11607551, 40.07783346, 28.62948585, 51.28216115, 23.60667   ],
#        [25.9677706 , 36.49627724, 25.40920807, 46.88600259, 21.54302391],
#        [23.23499778, 33.32780703, 22.75593682, 43.00707821, 19.73950669],
#        [20.86326543, 30.52221798, 20.58587373, 39.58174949, 18.16282017],
#        [18.80520436, 28.03560182, 18.82680555, 36.55441537, 16.78396393],
#        [17.01963837, 25.82954313, 17.41654994, 33.87648235, 15.57767819],
#        [15.47077611, 23.8704191 , 16.30160688, 31.50546751, 14.52195906],
#        [14.1275082 , 22.12878951, 15.43598843, 29.40421737, 13.59763676],
#        [12.96279606, 20.57886524, 14.78020368, 27.5402275 , 12.78800863],
#        [11.9531404 , 19.19804504, 14.3003783 , 25.88504974, 12.07851979],
#        [11.07811909, 17.96651187, 13.96749113, 24.41377586, 11.45648523],
#        [10.31998521, 16.866881  , 13.75671232, 23.10458765, 10.91084807],
#        [ 9.66331758, 15.88389325, 13.64682968, 21.9383648 , 10.43196906],
#        [ 9.09471691, 15.00414747, 13.61975164, 20.89834322, 10.01144346],
#        [ 8.60254151, 14.21586725, 13.66007667, 19.96981721,  9.6419417 ],
#        [ 8.17667756, 13.50869749, 13.75472041, 19.13987973,  9.31707061],
#        [ 7.80833931, 12.87352679, 13.8925929 , 18.39719604,  9.0312527 ],
#        [ 7.48989537, 12.30233259, 14.06431926, 17.73180622,  8.77962109],
#        [ 7.21471771, 11.78804591, 14.26199804, 17.13495296,  8.55792797],
#        [ 6.9770503 , 11.32443333, 14.4789923 , 16.59893128,  8.36246503],
#        [ 6.77189497, 10.90599389, 14.70974906, 16.11695743,  8.18999404],
#        [ 6.59491214, 10.52786905, 14.94964333, 15.68305442,  8.03768659],
#        [ 6.44233453, 10.18576398, 15.19484339, 15.29195219,  7.90307141],
#        [ 6.31089216,  9.87587881, 15.44219467, 14.93900025,  7.78398872],
#        [ 6.19774709,  9.59484853, 15.6891195 , 14.62009158,  7.67855026],
#        [ 6.10947583,  9.33969035, 15.93353079, 14.33159599,  7.58510464],
#        [ 6.04160922,  9.11666304, 16.17375771, 14.07427711,  7.50220711],
#        [ 5.98556545,  8.91572319, 16.40848175, 13.84805679,  7.42859316],
#        [ 5.93923029,  8.73286133, 16.63668169, 13.64378291,  7.36315564],
#        [ 5.90131364,  8.56636373, 16.85758649, 13.45879936,  7.3049247 ],
#        [ 5.87056099,  8.41459398, 17.07063478, 13.29118895,  7.25305044],
#        [ 5.84588929,  8.27610145, 17.27544016, 13.13914402,  7.20678764],
#        [ 5.82636661,  8.14962433, 17.47176158, 13.0010595 ,  7.16548259],
#        [ 5.81119186,  8.04275509, 17.659478  , 12.87551087,  7.12856152],
#        [ 5.79967704,  7.95201592, 17.83856678, 12.76123262,  7.09552054],
#        [ 5.79146197,  7.86931835, 18.00908527, 12.6570993 ,  7.06591687],
#        [ 5.78557752,  7.79360523, 18.17115526, 12.56229322,  7.03936119],
#        [ 5.781817  ,  7.72438457, 18.32494967, 12.47555143,  7.01551094],
#        [ 5.77983316,  7.6610133 , 18.48095445, 12.3962562 ,  6.99406452],
#        [ 5.77930386,  7.60294239, 18.70198953, 12.32370244,  6.97475618],
#        [ 5.77996358,  7.54968058, 18.91467302, 12.25725398,  6.95735161],
#        [ 5.78319862,  7.50079718, 19.11822093, 12.19634106,  6.93380137],
#        [ 5.78989141,  7.45602471, 19.31224506, 12.1404529 ,  6.90984317],
#        [ 5.78444774,  7.41693682, 19.4974435 , 12.08913109,  6.88471294],
#        [ 5.73211982,  7.32632393, 19.67358723, 12.04025949,  6.85576541],
#        [ 5.68905412,  7.24424285, 19.84083746, 11.98106534,  6.82932579],
#        [ 5.65331885,  7.17015566, 19.99940568, 11.86278872,  6.80545453],
#        [ 5.61954561,  7.10268388, 20.14953967, 11.75703956,  6.78393708],
#        [ 5.58781676,  7.04212823, 20.26831135, 11.66187123,  6.69837955],
#        [ 5.56160112,  6.98725422, 20.36955161, 11.57629522,  6.60840375],
#        [ 5.53996709,  6.93747643, 20.46526802, 11.49893177,  6.52735963],
#        [ 5.52223948,  6.89226944, 20.55570478, 11.42905708,  6.45461452],
#        [ 5.50783612,  6.8511668 , 20.64106097, 11.36586814,  6.38910327],
#        [ 5.49625563,  6.81339155, 20.72154689, 11.3086569 ,  6.33002881],
#        [ 5.48706649,  6.77932822, 20.79737586, 11.25707134,  6.27669399],
#        [ 5.47981038,  6.7482574 , 20.8692903 , 11.20317737,  6.22848297],
#        [ 5.47434814,  6.71988463, 20.93642012, 11.14233009,  6.18475099],
#        [ 5.47031528,  6.69395005, 20.99951883, 11.08777544,  6.14521301],
#        [ 5.46747588,  6.66995201, 21.05883226, 11.03788526,  6.09114197],
#        [ 5.46562956,  6.64822704, 21.11457969, 10.99252343,  6.04072257],
#        [ 5.46454311,  6.62832672, 21.16715371, 10.95121389,  5.99477724],
#        [ 5.46419335,  6.6100667 , 21.2136365 , 10.91355444,  5.95307816],
#        [ 5.46439872,  6.59310502, 21.25119391, 10.87958222,  5.91517421],
#        [ 5.46504889,  6.57767631, 21.2860444 , 10.84813075,  5.88102205],
#        [ 5.46605437,  6.56352009, 21.31937831, 10.82128041,  5.84954643],
#        [ 5.46729318,  6.55048776, 21.35059634, 10.79621776,  5.8208658 ],
#        [ 5.46903246,  6.53837162, 21.37904966, 10.77361034,  5.79468298],
#        [ 5.47084984,  6.52725584, 21.40660484, 10.75331469,  5.77120432],
#        [ 5.47283337,  6.51703539, 21.43238706, 10.7350707 ,  5.74925708],
#        [ 5.47492857,  6.507425  , 21.45652164, 10.71864951,  5.72918063],
#        [ 5.47709306,  6.49741813, 21.47912274, 10.70446282,  5.71043355],
#        [ 5.47929471,  6.48798341, 21.50028201, 10.69111834,  5.69223282],
#        [ 5.48150721,  6.47929092, 21.51916903, 10.67900233,  5.67527024],
#        [ 5.4837091 ,  6.47132651, 21.53774709, 10.66804929,  5.65968284],
#        [ 5.48585885,  6.46417824, 21.55517603, 10.65813213,  5.64536283],
#        [ 5.48797856,  6.45740592, 21.57144797, 10.64914054,  5.63219355],
#        [ 5.49005589,  6.45121931, 21.58428883, 10.64097855,  5.62007283],
#        [ 5.49207471,  6.44554706, 21.59637507, 10.63401842,  5.60933274],
#        [ 5.49402672,  6.44032878, 21.60784362, 10.62733675,  5.59902425],
#        [ 5.49590736,  6.43552272, 21.61860428, 10.62115376,  5.58949406],
#        [ 5.49771364,  6.43109343, 21.62866497, 10.61551014,  5.58070617],
#        [ 5.49939004,  6.4271692 , 21.63806694, 10.61036162,  5.57259295],
#        [ 5.50103257,  6.42335897, 21.64685306, 10.60565809,  5.56509664],
#        [ 5.50260807,  6.41984325, 21.65450093, 10.60135609,  5.55816646],
#        [ 5.50411042,  6.41661379, 21.66198366, 10.5977465 ,  5.55215387],
#        [ 5.50553816,  6.41363519, 21.66916111, 10.59425053,  5.54624034],
#        [ 5.50689249,  6.41088131, 21.67591073, 10.59093408,  5.54071225],
#        [ 5.5081754 ,  6.4083329 , 21.68221551, 10.58786235,  5.53559288],
#        [ 5.50938916,  6.40597354, 21.68809861, 10.58503856,  5.53085262],
#        [ 5.51053616,  6.40378833, 21.69358963, 10.58244358,  5.52645948],
#        [ 5.511545  ,  6.40176359, 21.69871587, 10.58005626,  5.52238568],
#        [ 5.51262921,  6.39988679, 21.70350175, 10.57785783,  5.51860654],
#        [ 5.51353269,  6.39814647, 21.70796966, 10.57583177,  5.51509961],
#        [ 5.51449855,  6.39653212, 21.71214043, 10.57396331,  5.51184427],
#        [ 5.51529891,  6.39503413, 21.71603355, 10.57223909,  5.50882158]])
